# %% [markdown]
# # Практические задания главы 5 «Основы языка определения данных» (решения на чистом SQL)

# %%
conn_str = "postgresql://postgres:postgres@postgres_basic.demodb:5432/demo"

# %%
# %reload_ext sql
# %sql $conn_str

# %% [markdown]
# ## Задание 1
#
# При использовании значений по умолчанию с ключевым словом `DEFAULT` возможны и ситуации, когда типичным будет не конкретное значение данных, а способ его получения. Например, если мы захотим фиксировать в каждой строке таблицы «Студенты» имя пользователя базы данных, добавившего эту строку в таблицу, тогда необходимо в определение таблицы добавить еще один столбец. Этот столбец по умолчанию будет получать значение, возвращаемое функцией current_user.
#
# ```sql
# CREATE TABLE students (
#     record_book numeric( 5 ) NOT NULL,
#     name text NOT NULL,
#     doc_ser numeric( 4 ),
#     doc_num numeric( 6 ),
#     who_adds_row text DEFAULT current_user, -- добавленный столбец
#     PRIMARY KEY ( record_book )
# );
# ```
#
# Эта функция — `current_user` — будет вызываться не при создании таблицы, а при вставке каждой строки. При этом в команде `INSERT` не требуется указывать значение для столбца `who_adds_row`, поскольку функция `current_user` будет вызываться самой СУБД PostgreSQL:
#
# ```sql
# INSERT INTO students ( record_book, name, doc_ser, doc_num )
#     VALUES ( 12300, 'Иванов Иван Иванович', 0402, 543281 );
# ```
#
# Давайте пойдем дальше и пожелаем фиксировать не только имя пользователя базы данных, добавившего строку в таблицу, но также и момент времени, когда
# это было сделано. Самостоятельно внесите модификацию в определение таблицы `students` для решения этой задачи, а затем выполните команду `INSERT` для проверки полученного решения.
#
# Если до выполнения этого упражнения вы еще не ознакомились с командой `ALTER TABLE`, то вместо модифицирования определения таблицы сначала удалите ее, а затем создайте заново:
#
# ```sql
# DROP TABLE students;
# CREATE TABLE students ...
# ```

# %% [markdown]
# ### Решение

# %%
# %%sql
# DROP TABLE IF EXISTS students CASCADE;
#
# CREATE TABLE IF NOT EXISTS students (
#     record_book numeric(5) NOT NULL,
#     name text NOT NULL,
#     doc_ser numeric(4),
#     doc_num numeric(6),
#     who_adds_row text DEFAULT current_user,
#     created_at timestamp DEFAULT current_timestamp,
#     PRIMARY KEY (record_book)
# );
#
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (12300, 'Иванов Иван Иванович', 0402, 543281)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# Done.
# 1 rows affected.
# [(Decimal('12300'), 'Иванов Иван Иванович', Decimal('402'), Decimal('543281'), 'postgres', datetime.datetime(2025, 6, 26, 10, 14, 34, 571388))]

# %% [markdown]
# ## Задание 2
#
# Посмотрите, какие ограничения уже наложены на атрибуты таблицы «Успеваемость» (`progress`). Воспользуйтесь командой `\d` утилиты psql. А теперь предложите для этой таблицы ограничение уровня таблицы.
#
# В качестве примера рассмотрим такой вариант. Добавьте в таблицу `progress` еще один атрибут — «Форма проверки знаний» (`test_form`), который может принимать только два значения: «экзамен» или «зачет». Тогда набор допустимых значений атрибута «Оценка» (`mark`) будет зависеть от того, экзамен или зачет предусмотрены по данной дисциплине. Если предусмотрен экзамен, тогда допускаются значения 3, 4, 5, если зачет — тогда 0 (не зачтено) или 1 (зачтено).
#
# Не забудьте, что значения `NULL` для атрибутов `test_form` и `mark` не допускаются.
#
# Новое ограничение может быть таким:
#
# ```sql
# ALTER TABLE progress
#     ADD CHECK (
#         ( test_form = 'экзамен' AND mark IN ( 3, 4, 5 ) )
#         OR
#         ( test_form = 'зачет' AND mark IN ( 0, 1 ) )
#     );
# ```
#
# Проверьте, как будет работать новое ограничение в модифицированной таблице `progress`. Для этого выполните команды `INSERT`, как удовлетворяющие ограничению, так и нарушающие его.
#
# В таблице уже было ограничение на допустимые значения атрибута `mark`. Как вы думаете, не будет ли оно конфликтовать с новым ограничением? Проверьте
# эту гипотезу. Если ограничения конфликтуют, тогда удалите старое ограничение и снова попробуйте добавить строки в таблицу.
#
# Подумайте, какое еще ограничение уровня таблицы можно предложить для этой таблицы?

# %% [markdown]
# ### Решение

# %% [markdown]
# #### Создание таблиц

# %%
# %%sql
# DROP TABLE IF EXISTS students, progress CASCADE;
#
# CREATE TABLE students (
#     record_book numeric(5) NOT NULL,
#     name text NOT NULL,
#     doc_ser numeric(4),
#     doc_num numeric(6),
#     PRIMARY KEY (record_book)
# );
#
# CREATE TABLE progress (
#     record_book numeric(5) NOT NULL,
#     subject text NOT NULL,
#     acad_year text NOT NULL,
#     term numeric(1) NOT NULL CHECK ( term IN (1, 2) ),
#     mark numeric(1) NOT NULL CHECK ( mark >= 3 AND mark <= 5 ) DEFAULT 5,
#     FOREIGN KEY (record_book)
#         REFERENCES students (record_book)
#         ON DELETE CASCADE
#         ON UPDATE CASCADE
# );
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# Done.
# Done.
# []

# %% [markdown]
# #### Добавление поля «Форма проверки знаний» (test_form)

# %%
# %%sql
# -- Можно сразу добавить ограничение на поле `test_form`
# ALTER TABLE progress
#     ADD COLUMN IF NOT EXISTS test_form varchar(10) NOT NULL CHECK ( test_form IN ('экзамен', 'зачет') );
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# []

# %% [markdown]
# #### Добавление ограничения для оценки с учетом формы проверки знаний

# %%
# %%sql
# ALTER TABLE progress
#     ADD CHECK (
#         (test_form = 'экзамен' AND mark IN (3, 4, 5))
#         OR
#         (test_form = 'зачет' AND mark IN (0, 1))
#     );
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# []

# %% [markdown]
# #### Добавление строк, удовлетворяющих ограничениям

# %%
# %%sql
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (12300, 'Иванов Иван Иванович', 402, 543281)
# ON CONFLICT DO NOTHING;
#
# INSERT INTO progress (record_book, subject, acad_year, term, mark, test_form)
#     VALUES
#         (12300, 'Предмет 1', '2025/2026', 1, 3, 'экзамен'),
#         (12300, 'Предмет 2', '2025/2026', 1, 4, 'экзамен'),
#         (12300, 'Предмет 3', '2025/2026', 1, 5, 'экзамен')
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# 3 rows affected.
# [(Decimal('12300'), 'Предмет 1', '2025/2026', Decimal('1'), Decimal('3'), 'экзамен'),
#  (Decimal('12300'), 'Предмет 2', '2025/2026', Decimal('1'), Decimal('4'), 'экзамен'),
#  (Decimal('12300'), 'Предмет 3', '2025/2026', Decimal('1'), Decimal('5'), 'экзамен')]

# %% [markdown]
# #### Добавление строк, не удовлетворяющих ограничениям

# %%
# %%sql
# INSERT INTO progress (record_book, subject, acad_year, term, mark, test_form)
#     VALUES
#         (12300, 'Предмет 4', '2025/2026', 1, 0, 'экзамен'),
#         (12300, 'Предмет 5', '2025/2026', 1, 1, 'экзамен'),
#         (12300, 'Предмет 6', '2025/2026', 2, 2, 'экзамен'),
#         (12300, 'Предмет 7', '2025/2026', 2, 6, 'экзамен');
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.CheckViolation) new row for relation "progress" violates check constraint "progress_check"
# DETAIL:  Failing row contains (12300, Предмет 4, 2025/2026, 1, 0, экзамен).
#
# [SQL: INSERT INTO progress (record_book, subject, acad_year, term, mark, test_form)
#     VALUES
#         (12300, 'Предмет 4', '2025/2026', 1, 0, 'экзамен'),
#         (12300, 'Предмет 5', '2025/2026', 1, 1, 'экзамен'),
#         (12300, 'Предмет 6', '2025/2026', 2, 2, 'экзамен'),
#         (12300, 'Предмет 7', '2025/2026', 2, 6, 'экзамен');]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# #### Конфликт ограничений

# %%
# %%sql
# -- Добавление оценок за зачет - валидная операция, но она конфликтует со старым ограничением для поля `mark`
# INSERT INTO progress (record_book, subject, acad_year, term, mark, test_form)
#     VALUES
#         (12300, 'Предмет 8', '2025/2026', 1, 0, 'зачет'),
#         (12300, 'Предмет 9', '2025/2026', 1, 1, 'зачет');
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.CheckViolation) new row for relation "progress" violates check constraint "progress_mark_check"
# DETAIL:  Failing row contains (12300, Предмет 8, 2025/2026, 1, 0, зачет).
#
# [SQL: -- Добавление оценок за зачет - валидная операция, но она конфликтует со старым ограничением для поля `mark`
# INSERT INTO progress (record_book, subject, acad_year, term, mark, test_form)
#     VALUES
#         (12300, 'Предмет 8', '2025/2026', 1, 0, 'зачет'),
#         (12300, 'Предмет 9', '2025/2026', 1, 1, 'зачет');]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
# %%sql
# -- Удаление старого ограничения для поля `mark`
# ALTER TABLE progress
#     DROP CONSTRAINT progress_mark_check;
#
# -- Добавление оценок за зачет
# INSERT INTO progress (record_book, subject, acad_year, term, mark, test_form)
#     VALUES
#         (12300, 'Предмет 8', '2025/2026', 1, 0, 'зачет'),
#         (12300, 'Предмет 9', '2025/2026', 1, 1, 'зачет');
#
# SELECT
#     s.name,
#     p.*
# FROM progress p
# JOIN students s ON s.record_book = p.record_book;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# 2 rows affected.
# 5 rows affected.
# [('Иванов Иван Иванович', Decimal('12300'), 'Предмет 1', '2025/2026', Decimal('1'), Decimal('3'), 'экзамен'),
#  ('Иванов Иван Иванович', Decimal('12300'), 'Предмет 2', '2025/2026', Decimal('1'), Decimal('4'), 'экзамен'),
#  ('Иванов Иван Иванович', Decimal('12300'), 'Предмет 3', '2025/2026', Decimal('1'), Decimal('5'), 'экзамен'),
#  ('Иванов Иван Иванович', Decimal('12300'), 'Предмет 8', '2025/2026', Decimal('1'), Decimal('0'), 'зачет'),
#  ('Иванов Иван Иванович', Decimal('12300'), 'Предмет 9', '2025/2026', Decimal('1'), Decimal('1'), 'зачет')]

# %% [markdown]
# ## Задание 3
#
# В определении таблицы «Успеваемость» (`progress`) на атрибуты `term` и `mark` наложены как ограничения `CHECK`, так и ограничение `NOT NULL`. Возникает вопрос: не является ли ограничение `NOT NULL` избыточным? Ведь в ограничении `CHECK` явно указаны допустимые значения.
#
# Проверьте гипотезу об избыточности ограничения `NOT NULL` в данном случае. Для этого модифицируйте таблицу, убрав ограничение `NOT NULL`, и попробуйте добавить в нее строку с отсутствующим значением атрибута `term` (или `mark`).

# %% [markdown]
# ### Решение

# %%
# %%sql
# ALTER TABLE IF EXISTS progress
#     ALTER COLUMN term DROP NOT NULL,
#     ALTER COLUMN mark DROP NOT NULL;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# []

# %%
# %%sql
# -- Без ограничения `NOT NULL` поле `term` будет равно `NULL`, а поле `mark` будет равно его дефолтному значению
# INSERT INTO progress (record_book, subject, acad_year, test_form)
#     VALUES (12300, 'Предмет без семестра и оценки', '2025/2026', 'экзамен')
# RETURNING *
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# [(Decimal('12300'), 'Предмет без семестра и оценки', '2025/2026', None, Decimal('5'), 'экзамен')]

# %%
# %%sql
# -- Без ограничения `NOT NULL` поля `term` и `mark` будут равны `NULL`
# INSERT INTO progress (record_book, subject, acad_year, term, mark, test_form)
#     VALUES (12300, 'Предмет без семестра и оценки', '2025/2026', null, null, 'экзамен')
# RETURNING *
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# [(Decimal('12300'), 'Предмет без семестра и оценки', '2025/2026', None, None, 'экзамен')]

# %% [markdown]
# ## Задание 4
#
# В определении таблицы «Успеваемость» (`progress`) для атрибута `mark` не только задано ограничение `CHECK`, но и установлено значение по умолчанию с помощью ключевого слова `DEFAULT`:
#
# ```sql
# ...
# mark numeric( 1 ) NOT NULL
#     CHECK ( mark >= 3 AND mark <= 5 )
#     DEFAULT 5,
# ...
# ```
#
# Как вы думаете, что будет, если в ограничении `DEFAULT` мы «случайно» допустим ошибку, написав `DEFAULT` 6? Если в команде `INSERT` не указать значение для атрибута `mark`, то на каком этапе эта ошибка будет выявлена: уже на этапе создания таблицы или только при вставке строки в нее?
#
# Вот эта команда может быть вам полезной для проверки гипотезы, поскольку в ней отсутствует передаваемое значение для атрибута mark:
#
# ```sql
# INSERT INTO progress ( record_book, subject, acad_year, term )
#     VALUES ( 12300, 'Физика', '2016/2017',1 );
# ```

# %% [markdown]
# ### Решение

# %%
# %%sql
# DROP TABLE IF EXISTS progress;
#
# -- На этапе создания таблицы ошибки не будет, несмотря на то, что дефолтное значение не соответствует ограничению `CHECK`
# CREATE TABLE progress (
#     record_book numeric(5) NOT NULL,
#     subject text NOT NULL,
#     acad_year text NOT NULL,
#     term numeric(1) NOT NULL CHECK ( term IN (1, 2) ),
#     mark numeric(1) NOT NULL CHECK ( mark >= 3 AND mark <= 5 ) DEFAULT 6,
#     FOREIGN KEY (record_book)
#         REFERENCES students (record_book)
#         ON DELETE CASCADE
#         ON UPDATE CASCADE
# );
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# Done.
# []

# %%
# %%sql
# -- При вставке будет ошибка, потому что сначала должно быть вычислено значение, потом проверено ограничение
# INSERT INTO progress (record_book, subject, acad_year, term)
#     VALUES (12300, 'Физика', '2016/2017', 1)
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.CheckViolation) new row for relation "progress" violates check constraint "progress_mark_check"
# DETAIL:  Failing row contains (12300, Физика, 2016/2017, 1, 6).
#
# [SQL: -- При вставке будет ошибка, потому что сначала должно быть вычислено значение, потом проверено ограничение
# INSERT INTO progress (record_book, subject, acad_year, term)
#     VALUES (12300, 'Физика', '2016/2017', 1)]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# ## Задание 5
#
# В стандарте SQL сказано, что при наличии ограничения уникальности, включающего один или более столбцов, все же возможны повторяющиеся значения этих столбцов в разных строках, но лишь в том случае, если это значения `NULL`. PostgreSQL придерживается такого же подхода.
#
# Модифицируйте определение таблицы «Студенты» (`students`), добавив ограничение уникальности по двум столбцам: `doc_ser` и `doc_num`. А затем проверьте вышеприведенное утверждение, добавив в таблицу не только строки, содержащие конкретные значения этих двух столбцов, но также и по две строки, имеющие следующие свойства:
#
# * одинаковые значения столбца `doc_ser` и `NULL`-значения столбца `doc_num`;
# * `NULL`-значения столбца `doc_num` и столбца `doc_ser`.
#
# Подобные вещи возможны, так как `NULL`-значения не считаются совпадающими. Это можно проверить с помощью команды
#
# ```sql
# SELECT (null = null);
# ```
#
# Она даст такой результат (т. е. `NULL`):
#
# ```
# ?column?
# ----------
# (1 строка)
# ```

# %% [markdown]
# ### Решение

# %%
# %%sql
# -- Удаление записей
# DELETE FROM students;
#
# -- Добавление ограничения уникальности
# ALTER TABLE students
#     ADD CONSTRAINT "students_doc_ser_doc_num_unique" UNIQUE (doc_ser, doc_num);
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# Done.
# []

# %%
# %%sql
# -- Одинаковые значения столбца `doc_ser` и `NULL`-значения столбца `doc_num`
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES
#         (11111, 'Васильев Василий Васильевич', 1234, null),
#         (11112, 'Петров Петр Петрович', 1234, null)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 2 rows affected.
# [(Decimal('11111'), 'Васильев Василий Васильевич', Decimal('1234'), None),
#  (Decimal('11112'), 'Петров Петр Петрович', Decimal('1234'), None)]

# %%
# %%sql
# -- Одинаковые значения столбца `doc_num` и `NULL`-значения столбца `doc_ser`
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES
#         (11113, 'Михайлов Михаил Михайлович', null, 123456),
#         (11114, 'Власов Влас Власович', null, 123456)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 2 rows affected.
# [(Decimal('11113'), 'Михайлов Михаил Михайлович', None, Decimal('123456')),
#  (Decimal('11114'), 'Власов Влас Власович', None, Decimal('123456'))]

# %%
# %%sql
# -- `NULL`-значения столбца `doc_num` и столбца `doc_ser`
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES
#         (11115, 'Сидоров Сидр Сидорович', null, null),
#         (11116, 'Харитонов Харитон Харитонович', null, null)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 2 rows affected.
# [(Decimal('11115'), 'Сидоров Сидр Сидорович', None, None),
#  (Decimal('11116'), 'Харитонов Харитон Харитонович', None, None)]

# %% [markdown]
# ## Задание 6
#
# Модифицируйте определения таблиц «Студенты» (`students`) и «Успеваемость» (`progress`). В таблице `students` в качестве первичного ключа назначьте комбинацию атрибутов `doc_ser` и `doc_num`, а в таблице `progress` соответствующим образом измените определение внешнего ключа.
#
# ```sql
# CREATE TABLE students (
#     record_book numeric(5) NOT NULL UNIQUE,
#     name text NOT NULL,
#     doc_ser numeric(4),
#     doc_num numeric(6),
#     PRIMARY KEY (doc_ser, doc_num)
# );
# ```
#
# Обратите внимание, что для атрибутов `doc_ser` и `doc_num` можно не указывать ограничение `NOT NULL`: они входят в состав первичного ключа, а в нем `NULL`-значения не допускаются, поэтому ограничение `NOT NULL` фактически подразумевается при включении атрибута в состав первичного ключа.
#
# ```sql
# CREATE TABLE progress (
#     doc_ser numeric(4),
#     doc_num numeric(6),
#     subject text NOT NULL,
#     acad_year text NOT NULL,
#     term numeric( 1 ) NOT NULL CHECK ( term = 1 OR term = 2 ),
#     mark numeric( 1 ) NOT NULL CHECK ( mark >= 3 AND mark <= 5 )
#         DEFAULT 5,
#     FOREIGN KEY (doc_ser, doc_num)
#         REFERENCES students (doc_ser, doc_num)
#         ON DELETE CASCADE
#         ON UPDATE CASCADE
# );
# ```
#
# Теперь и первичный, и внешний ключи — составные. Проверьте их действие, добавив несколько строк в каждую таблицу.

# %% [markdown]
# ### Решение

# %%
# %%sql
# DROP TABLE IF EXISTS students, progress CASCADE;
#
# CREATE TABLE students (
#     record_book numeric(5) NOT NULL UNIQUE,
#     name text NOT NULL,
#     doc_ser numeric(4),
#     doc_num numeric(6),
#     PRIMARY KEY (doc_ser, doc_num)
# );
#
# CREATE TABLE progress (
#     doc_ser numeric(4),
#     doc_num numeric(6),
#     subject text NOT NULL,
#     acad_year text NOT NULL,
#     term numeric( 1 ) NOT NULL CHECK ( term = 1 OR term = 2 ),
#     mark numeric( 1 ) NOT NULL CHECK ( mark >= 3 AND mark <= 5 )
#         DEFAULT 5,
#     FOREIGN KEY (doc_ser, doc_num)
#         REFERENCES students (doc_ser, doc_num)
#         ON DELETE CASCADE
#         ON UPDATE CASCADE
# );
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# Done.
# Done.
# []

# %% [markdown]
# #### Добавление записей в таблицу `students`

# %%
# %%sql
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES
#         (11111, 'Вася', 1234, 123456),
#         (11112, 'Петя', 1234, 123457),
#         (11113, 'Миша', 1235, 123456),
#         (11114, 'Коля', 1235, 123457)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 4 rows affected.
# [(Decimal('11111'), 'Вася', Decimal('1234'), Decimal('123456')),
#  (Decimal('11112'), 'Петя', Decimal('1234'), Decimal('123457')),
#  (Decimal('11113'), 'Миша', Decimal('1235'), Decimal('123456')),
#  (Decimal('11114'), 'Коля', Decimal('1235'), Decimal('123457'))]

# %% [markdown]
# #### Попытка добавить невалидный первичный ключ в таблицу `students`

# %%
# %%sql
# -- NULL в поле `doc_ser`
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11115, 'Федя', null, 123456);
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.NotNullViolation) null value in column "doc_ser" of relation "students" violates not-null constraint
# DETAIL:  Failing row contains (11115, Федя, null, 123456).
#
# [SQL: -- NULL в поле `doc_ser`
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11115, 'Федя', null, 123456);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
# %%sql
# -- NULL в поле `doc_num`
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11115, 'Федя', 1234, null);
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.NotNullViolation) null value in column "doc_num" of relation "students" violates not-null constraint
# DETAIL:  Failing row contains (11115, Федя, 1234, null).
#
# [SQL: -- NULL в поле `doc_num`
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11115, 'Федя', 1234, null);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
# %%sql
# -- Неуникальный первичный ключ
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11115, 'Федя', 1234, 123456);
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "students_pkey"
# DETAIL:  Key (doc_ser, doc_num)=(1234, 123456) already exists.
#
# [SQL: -- Неуникальный первичный ключ
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11115, 'Федя', 1234, 123456);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# #### Добавление записей в таблицу `progress`

# %%
# %%sql
# INSERT INTO progress (doc_ser, doc_num, subject, acad_year, term)
#     VALUES
#         (1234, 123456, 'Программирование', '2025/2026', 1),
#         (1234, 123457, 'Программирование', '2025/2026', 1),
#         (1235, 123456, 'Программирование', '2025/2026', 1),
#         (1235, 123457, 'Программирование', '2025/2026', 1)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 4 rows affected.
# [(Decimal('1234'), Decimal('123456'), 'Программирование', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('1234'), Decimal('123457'), 'Программирование', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('1235'), Decimal('123456'), 'Программирование', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('1235'), Decimal('123457'), 'Программирование', '2025/2026', Decimal('1'), Decimal('5'))]

# %% [markdown]
# #### Попытка добавить невалидный вторичный ключ в таблицу `progress`

# %%
# %%sql
# -- NULL в поле `doc_ser`
# INSERT INTO progress (doc_ser, doc_num, subject, acad_year, term)
#     VALUES (null, 123456, 'Программирование', '2025/2026', 1)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# [(None, Decimal('123456'), 'Программирование', '2025/2026', Decimal('1'), Decimal('5'))]

# %%
# %%sql
# -- NULL в поле `doc_num`
# INSERT INTO progress (doc_ser, doc_num, subject, acad_year, term)
#     VALUES (1234, null, 'Программирование', '2025/2026', 1)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# [(Decimal('1234'), None, 'Программирование', '2025/2026', Decimal('1'), Decimal('5'))]

# %%
# %%sql
# -- Неуникальный вторичный ключ
# INSERT INTO progress (doc_ser, doc_num, subject, acad_year, term)
#     VALUES (1234, 123456, 'Программирование', '2025/2026', 1)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# [(Decimal('1234'), Decimal('123456'), 'Программирование', '2025/2026', Decimal('1'), Decimal('5'))]

# %%
# %%sql
# -- Несуществующий вторичный ключ (в `students` нет таких данных)
# INSERT INTO progress (doc_ser, doc_num, subject, acad_year, term)
#     VALUES (4321, 654321, 'Программирование', '2025/2026', 1)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.ForeignKeyViolation) insert or update on table "progress" violates foreign key constraint "progress_doc_ser_doc_num_fkey"
# DETAIL:  Key (doc_ser, doc_num)=(4321, 654321) is not present in table "students".
#
# [SQL: -- Несуществующий вторичный ключ (в `students` нет таких данных)
# INSERT INTO progress (doc_ser, doc_num, subject, acad_year, term)
#     VALUES (4321, 654321, 'Программирование', '2025/2026', 1)
# RETURNING *;]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# #### Добавление ограничений для вторичного ключа

# %%
# %%sql
# -- Удаление записей
# DELETE FROM progress;
#
# -- Добавление ограничений
# ALTER TABLE progress
#     ALTER COLUMN doc_ser SET NOT NULL,
#     ALTER COLUMN doc_num SET NOT NULL,
#     ADD CONSTRAINT "progress_doc_ser_doc_num_unique" UNIQUE (doc_ser, doc_num);
#
# -- Вставка записей
# INSERT INTO progress (doc_ser, doc_num, subject, acad_year, term)
#     VALUES
#         (1234, 123456, 'Программирование', '2025/2026', 1),
#         (1234, 123457, 'Программирование', '2025/2026', 1),
#         (1235, 123456, 'Программирование', '2025/2026', 1),
#         (1235, 123457, 'Программирование', '2025/2026', 1)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 7 rows affected.
# Done.
# 4 rows affected.
# [(Decimal('1234'), Decimal('123456'), 'Программирование', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('1234'), Decimal('123457'), 'Программирование', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('1235'), Decimal('123456'), 'Программирование', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('1235'), Decimal('123457'), 'Программирование', '2025/2026', Decimal('1'), Decimal('5'))]

# %% [markdown]
# #### Новая попытка добавить невалидный вторичный ключ в таблицу `progress`

# %%
# %%sql
# -- NULL в поле `doc_ser`
# INSERT INTO progress (doc_ser, doc_num, subject, acad_year, term)
#     VALUES (null, 123456, 'Программирование', '2025/2026', 1)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.NotNullViolation) null value in column "doc_ser" of relation "progress" violates not-null constraint
# DETAIL:  Failing row contains (null, 123456, Программирование, 2025/2026, 1, 5).
#
# [SQL: -- NULL в поле `doc_ser`
# INSERT INTO progress (doc_ser, doc_num, subject, acad_year, term)
#     VALUES (null, 123456, 'Программирование', '2025/2026', 1)
# RETURNING *;]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
# %%sql
# -- NULL в поле `doc_num`
# INSERT INTO progress (doc_ser, doc_num, subject, acad_year, term)
#     VALUES (1234, null, 'Программирование', '2025/2026', 1)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.NotNullViolation) null value in column "doc_num" of relation "progress" violates not-null constraint
# DETAIL:  Failing row contains (1234, null, Программирование, 2025/2026, 1, 5).
#
# [SQL: -- NULL в поле `doc_num`
# INSERT INTO progress (doc_ser, doc_num, subject, acad_year, term)
#     VALUES (1234, null, 'Программирование', '2025/2026', 1)
# RETURNING *;]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
# %%sql
# -- Неуникальный вторичный ключ
# INSERT INTO progress (doc_ser, doc_num, subject, acad_year, term)
#     VALUES (1234, 123456, 'Программирование', '2025/2026', 1)
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "progress_doc_ser_doc_num_unique"
# DETAIL:  Key (doc_ser, doc_num)=(1234, 123456) already exists.
#
# [SQL: -- Неуникальный вторичный ключ
# INSERT INTO progress (doc_ser, doc_num, subject, acad_year, term)
#     VALUES (1234, 123456, 'Программирование', '2025/2026', 1)
# RETURNING *;]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# ## Задание 7
#
# Модифицируйте определение таблицы «Успеваемость» (`progress`), а если потребуется, то и определение таблицы «Студенты» (`students`), чтобы изучить
# все варианты реагирования СУБД на обновление строк в ссылочной таблице, в данном случае — `students`. Последовательно изменяйте определение внешнего ключа таблицы `progress`, испробовав варианты `ON UPDATE CASCADE`, `ON UPDATE RESTRICT`, `ON UPDATE SET NULL` и `ON UPDATE SET DEFAULT`. Для получения информативной картины введите несколько строк в обе таблицы, а затем выполняйте операцию `UPDATE`, подбирая значения ключевых атрибутов таким образом, чтобы вызвать ожидаемую реакцию СУБД.
#
# Учтите, что при использовании фразы `ON UPDATE SET DEFAULT` необходимо, чтобы, во-первых, с помощью ключевого слова `DEFAULT` было установлено значение по умолчанию для атрибута внешнего ключа в ссылающейся таблице, а во-вторых, это значение по умолчанию все равно должно присутствовать в одной из строк ссылочной таблицы. Как вы считаете, с учетом сказанного, возможно ли использование `ON UPDATE SET DEFAULT` в нашем случае?
#
# Попробуйте обосновать или, наоборот, опровергнуть целесообразность использования каждой из этих политик — `CASCADE`, `RESTRICT`, `SET NULL` и `SET DEFAULT` — при выполнении операции `UPDATE` в реальной информационной системе, предназначенной для учета успеваемости студентов.

# %% [markdown]
# ### Решение

# %%
# %%sql
# DROP TABLE IF EXISTS students, progress CASCADE;
#
# CREATE TABLE students (
#     record_book numeric(5) NOT NULL UNIQUE,
#     name text NOT NULL,
#     doc_ser numeric(4),
#     doc_num numeric(6),
#     PRIMARY KEY (doc_ser, doc_num)
# );
#
# CREATE TABLE progress (
#     doc_ser numeric(4),
#     doc_num numeric(6),
#     subject text NOT NULL,
#     acad_year text NOT NULL,
#     term numeric( 1 ) NOT NULL CHECK ( term = 1 OR term = 2 ),
#     mark numeric( 1 ) NOT NULL CHECK ( mark >= 3 AND mark <= 5 )
#         DEFAULT 5,
#     CONSTRAINT progress_doc_ser_doc_num_fkey
#         FOREIGN KEY (doc_ser, doc_num)
#         REFERENCES students (doc_ser, doc_num)
# );
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# Done.
# Done.
# []

# %% [markdown]
# #### Демонстрация `ON UPDATE RESTRICT`

# %% [markdown]
# В нашем случае это недопустимая политика, потому что не позволит исправить серию и номер документа, если они были введены неправильно. Чтобы исправить серию и номер придется удалить студента и все его оценки, а затем внести их все заново с учетом исправлений.

# %%
# %%sql
# -- Модификация ограничения
# ALTER TABLE IF EXISTS progress
#     DROP CONSTRAINT IF EXISTS progress_doc_ser_doc_num_fkey;
#
# ALTER TABLE IF EXISTS progress
#     ADD CONSTRAINT progress_doc_ser_doc_num_fkey
#         FOREIGN KEY (doc_ser, doc_num)
#         REFERENCES students (doc_ser, doc_num) ON UPDATE RESTRICT;
#
# -- Удаление записей
# DELETE FROM progress;
# DELETE FROM students;
#
# -- Добавление записей в `students`
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (22222, 'Иванов Иван Иванович', 2222, 222222);
#
# -- Добавление записей в `progress`
# INSERT INTO progress(doc_ser, doc_num, subject, acad_year, term)
#     VALUES
#         (2222, 222222, 'SQL', '2025/2026', 1),
#         (2222, 222222, 'Python', '2025/2026', 1),
#         (2222, 222222, 'Golang', '2025/2026', 1);
#
# -- Обновление студента запрещено, т.к. есть ссылающиеся записи в `progress`
# UPDATE students
#     SET
#         doc_ser = 1234,
#         doc_num = 567890
#     WHERE
#         record_book = 22222;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# Done.
# 0 rows affected.
# 0 rows affected.
# 1 rows affected.
# 3 rows affected.
# (psycopg2.errors.ForeignKeyViolation) update or delete on table "students" violates foreign key constraint "progress_doc_ser_doc_num_fkey" on table "progress"
# DETAIL:  Key (doc_ser, doc_num)=(2222, 222222) is still referenced from table "progress".
#
# [SQL: -- Обновление студента запрещено, т.к. есть ссылающиеся записи в `progress`
# UPDATE students
#     SET
#         doc_ser = 1234,
#         doc_num = 567890
#     WHERE
#         record_book = 22222;]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# #### Демонстрация `ON UPDATE SET NULL`

# %% [markdown]
# В нашем случае это недопустимая политика, потому что, во-первых, студент «потеряет» все свои оценки при изменении серии и номера, а во-вторых, в БД останутся ничейные оценки.

# %%
# %%sql
# -- Модификация ограничения
# ALTER TABLE IF EXISTS progress
#     DROP CONSTRAINT IF EXISTS progress_doc_ser_doc_num_fkey;
#
# ALTER TABLE IF EXISTS progress
#     ADD CONSTRAINT progress_doc_ser_doc_num_fkey
#         FOREIGN KEY (doc_ser, doc_num)
#         REFERENCES students (doc_ser, doc_num) ON UPDATE SET NULL;
#
# -- Удаление записей
# DELETE FROM progress;
# DELETE FROM students;
#
# -- Добавление записей в `students`
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (33333, 'Иванов Иван Иванович', 3333, 333333);
#
# -- Добавление записей в `progress`
# INSERT INTO progress(doc_ser, doc_num, subject, acad_year, term)
#     VALUES
#         (3333, 333333, 'SQL', '2025/2026', 1),
#         (3333, 333333, 'Python', '2025/2026', 1),
#         (3333, 333333, 'Golang', '2025/2026', 1);
#
# -- Обновление студента
# UPDATE students
#     SET
#         doc_ser = 1234,
#         doc_num = 567890
#     WHERE
#         record_book = 33333;
#
# -- В `progress` появились записи с NULL
# SELECT * FROM progress;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# Done.
# 3 rows affected.
# 1 rows affected.
# 1 rows affected.
# 3 rows affected.
# 1 rows affected.
# 3 rows affected.
# [(None, None, 'SQL', '2025/2026', Decimal('1'), Decimal('5')),
#  (None, None, 'Python', '2025/2026', Decimal('1'), Decimal('5')),
#  (None, None, 'Golang', '2025/2026', Decimal('1'), Decimal('5'))]

# %% [markdown]
# #### Демонстрация `ON UPDATE SET DEFAULT`

# %% [markdown]
# В нашем случае это недопустимая политика, потому что, во-первых, студент «потеряет» все свои оценки при изменении серии и номера, а во-вторых не бывает дефолтных студентов.

# %%
# %%sql
# -- Модификация ограничения
# ALTER TABLE IF EXISTS progress
#     DROP CONSTRAINT IF EXISTS progress_doc_ser_doc_num_fkey;
#
# ALTER TABLE IF EXISTS progress
#     ADD CONSTRAINT progress_doc_ser_doc_num_fkey
#         FOREIGN KEY (doc_ser, doc_num)
#         REFERENCES students (doc_ser, doc_num) ON UPDATE SET DEFAULT;
#
# -- Добавление дефолтного значения
# -- Нужно только для демонстрации `ON UPDATE SET DEFAULT`. С точки зрения безнес-логики операция `SET DEFAULT` недопустима,
# -- потому что не бывает дефолтных студентов
# ALTER TABLE IF EXISTS progress
#     ALTER COLUMN doc_ser SET DEFAULT 0000,
#     ALTER COLUMN doc_num SET DEFAULT 000000;
#
# -- Удаление записей
# DELETE FROM progress;
# DELETE FROM students;
#
# -- Добавление записей в `students`
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES
#         (00000, 'Дефолтный студент', 0000, 000000),
#         (44444, 'Иванов Иван Иванович', 4444, 444444);
#
# -- Добавление записей в `progress`
# INSERT INTO progress(doc_ser, doc_num, subject, acad_year, term)
#     VALUES
#         (4444, 444444, 'SQL', '2025/2026', 1),
#         (4444, 444444, 'Python', '2025/2026', 1),
#         (4444, 444444, 'Golang', '2025/2026', 1);
#
# -- Обновление студента
# UPDATE students
#     SET
#         doc_ser = 1234,
#         doc_num = 567890
#     WHERE
#         record_book = 44444;
#
# -- Теперь оценки принадлежат дефолтному студенту
# SELECT
#     s.record_book,
#     s.name,
#     p.*
# FROM students s
# JOIN progress p ON p.doc_ser = s.doc_ser AND p.doc_num = s.doc_num;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# Done.
# Done.
# 3 rows affected.
# 1 rows affected.
# 2 rows affected.
# 3 rows affected.
# 1 rows affected.
# 3 rows affected.
# [(Decimal('0'), 'Дефолтный студент', Decimal('0'), Decimal('0'), 'SQL', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('0'), 'Дефолтный студент', Decimal('0'), Decimal('0'), 'Python', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('0'), 'Дефолтный студент', Decimal('0'), Decimal('0'), 'Golang', '2025/2026', Decimal('1'), Decimal('5'))]

# %% [markdown]
# #### Демонстрация `ON UPDATE CASCADE`

# %% [markdown]
# Это самая подходящая политика с точки зрения безнес-логики, потому что позволяет исправить серию и номер документа, если они были введены неправильно.

# %%
# %%sql
# -- Модификация ограничения
# ALTER TABLE IF EXISTS progress
#     DROP CONSTRAINT IF EXISTS progress_doc_ser_doc_num_fkey;
#
# ALTER TABLE IF EXISTS progress
#     ADD CONSTRAINT progress_doc_ser_doc_num_fkey
#         FOREIGN KEY (doc_ser, doc_num)
#         REFERENCES students (doc_ser, doc_num) ON UPDATE CASCADE;
#
# -- Удаление записей
# DELETE FROM progress;
# DELETE FROM students;
#
# -- Добавление записей в `students`
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11111, 'Иванов Иван Иванович', 1111, 111111);
#
# -- Добавление записей в `progress`
# INSERT INTO progress(doc_ser, doc_num, subject, acad_year, term)
#     VALUES
#         (1111, 111111, 'SQL', '2025/2026', 1),
#         (1111, 111111, 'Python', '2025/2026', 1),
#         (1111, 111111, 'Golang', '2025/2026', 1);
#
# -- Обновление студента
# UPDATE students
#     SET
#         doc_ser = 1234,
#         doc_num = 567890
#     WHERE
#         record_book = 11111;
#
# -- Обновился ключ в `progress`
# SELECT * FROM progress;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# Done.
# 3 rows affected.
# 2 rows affected.
# 1 rows affected.
# 3 rows affected.
# 1 rows affected.
# 3 rows affected.
# [(Decimal('1234'), Decimal('567890'), 'SQL', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('1234'), Decimal('567890'), 'Python', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('1234'), Decimal('567890'), 'Golang', '2025/2026', Decimal('1'), Decimal('5'))]

# %% [markdown]
# ## Задание 8
#
# В таблице «Успеваемость» (`progress`) есть атрибут «Учебная дисциплина» (`subject`). Это текстовый атрибут. Одинаковые наименования учебных дисциплин записываются в таблицу progress многократно. Создайте еще одну таблицу — «Учебные дисциплины» (`subjects`), в которой будет два атрибута: «Идентификатор учебной дисциплины» (`subject_id`) и «Учебная дисциплина» (`subject`). Тип данных первого из них будет `integer`, а второго — `text`. В качестве первичного ключа будет служить `subject_id`, а второй атрибут будет уникальным. Введите в новую таблицу две-три строки для различных учебных дисциплин.
#
# Модифицируйте таблицу `progress`, заменив атрибут `subject` на `subject_id`. Тип данных нового атрибута будет `integer`. Поскольку тип данных изменится, то для замены первоначальных значений, хранящихся в этом столбце, на новые придется использовать конструкцию `USING` (о ней говорится в тексте главы).
#
# Добавьте в определение таблицы `progress` еще один внешний ключ, который будет ссылаться на таблицу `subjects`. В составе этого внешнего ключа будет только один атрибут — `subject_id`. Мы видим, что таблица может иметь больше одного внешнего ключа. Таким образом, структура связей в реальной базе данных может оказаться весьма сложной.
#
# Теперь введите несколько строк и в таблицу `progress`, учитывая ее связь с новой таблицей `subjects`.

# %% [markdown]
# ### Решение

# %%
# %%sql
# DROP TABLE IF EXISTS students, progress, subjects CASCADE;
#
# CREATE TABLE students (
#     record_book numeric(5) NOT NULL UNIQUE,
#     name text NOT NULL,
#     doc_ser numeric(4),
#     doc_num numeric(6),
#     PRIMARY KEY (doc_ser, doc_num)
# );
#
# CREATE TABLE progress (
#     doc_ser numeric(4),
#     doc_num numeric(6),
#     subject text NOT NULL,
#     acad_year text NOT NULL,
#     term numeric( 1 ) NOT NULL CHECK ( term = 1 OR term = 2 ),
#     mark numeric( 1 ) NOT NULL CHECK ( mark >= 3 AND mark <= 5 )
#         DEFAULT 5,
#     CONSTRAINT progress_doc_ser_doc_num_fkey
#         FOREIGN KEY (doc_ser, doc_num)
#         REFERENCES students (doc_ser, doc_num)
#         ON UPDATE CASCADE
#         ON DELETE CASCADE
# );
#
# CREATE TABLE IF NOT EXISTS subjects (
#     subject_id serial PRIMARY KEY,
#     subject text UNIQUE NOT NULL
# );
#
# INSERT INTO subjects (subject)
#     VALUES ('SQL'), ('Python'), ('Golang')
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# Done.
# Done.
# Done.
# 3 rows affected.
# [(1, 'SQL'), (2, 'Python'), (3, 'Golang')]

# %%
# %%sql
# -- Добавление записей в `students`
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11111, 'Иванов Иван Иванович', 1111, 111111);
#
# -- Добавление записей в `progress`
# INSERT INTO progress(doc_ser, doc_num, subject, acad_year, term)
#     VALUES
#         (1111, 111111, 'SQL', '2025/2026', 1),
#         (1111, 111111, 'Python', '2025/2026', 1),
#         (1111, 111111, 'Golang', '2025/2026', 1);
#
# SELECT * FROM progress;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# 3 rows affected.
# 3 rows affected.
# [(Decimal('1111'), Decimal('111111'), 'SQL', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('1111'), Decimal('111111'), 'Python', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('1111'), Decimal('111111'), 'Golang', '2025/2026', Decimal('1'), Decimal('5'))]

# %%
# %%sql
# -- Модификация поля `progress.subject` и добавление ограничения
# ALTER TABLE IF EXISTS progress
#     ALTER COLUMN subject SET DATA TYPE integer
#         USING (
#             CASE
#                 WHEN subject = 'SQL' THEN 1
#                 WHEN subject = 'Python' THEN 2
#                 WHEN subject = 'Golang' THEN 3
#                 ELSE 0
#             END
#         ),
#     ADD CONSTRAINT progress_subject_fkey FOREIGN KEY (subject) REFERENCES subjects (subject_id);
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# []

# %%
# %%sql
# SELECT
#     p.doc_ser,
#     p.doc_num,
#     p.subject as "subject_id",
#     s.subject,
#     p.acad_year,
#     p.term,
#     p.mark
# FROM progress p
# JOIN subjects s ON s.subject_id = p.subject;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 3 rows affected.
# [(Decimal('1111'), Decimal('111111'), 1, 'SQL', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('1111'), Decimal('111111'), 2, 'Python', '2025/2026', Decimal('1'), Decimal('5')),
#  (Decimal('1111'), Decimal('111111'), 3, 'Golang', '2025/2026', Decimal('1'), Decimal('5'))]

# %% [markdown]
# ## Задание 9
#
# В таблице «Студенты» (`students`) есть текстовый атрибут `name`, на который наложено ограничение `NOT NULL`. Как вы думаете, что будет, если при вводе новой строки в эту таблицу дать атрибуту `name` в качестве значения пустую строку? Например:
# ```sql
# INSERT INTO students ( record_book, name, doc_ser, doc_num )
# VALUES ( 12300, '', 0402, 543281 );
# ```
#
# Наверное, проектируя эту таблицу, мы хотели бы все же, чтобы пустые строки в качестве значения атрибута name не проходили в базу данных? Какое решение вы можете предложить? Видимо, нужно добавить ограничение `CHECK` для столбца `name`. Если вы еще не изучили команду `ALTER TABLE`, то удалите таблицу `students` и создайте ее заново с учетом нового ограничения, а если вы уже познакомились с командой `ALTER TABLE`, то сделайте так:
# ```sql
# ALTER TABLE students ADD CHECK ( name <> '' );
# ```
#
# Добавив ограничение, попробуйте теперь вставить в таблицу `students` строку (row), в которой значение атрибута `name` было бы пустой строкой (string).
#
# Давайте продолжим эксперименты и предложим в качестве значения атрибута `name` строку, содержащую сначала один пробел, а потом — два пробела.
# ```sql
# INSERT INTO students VALUES ( 12346, ' ', 0406, 112233 );
# INSERT INTO students VALUES ( 12347, ' ', 0407, 112234 );
# ```
#
# Для того чтобы «увидеть» эти пробелы в выборке, сделаем так:
# ```sql
# SELECT *, length( name ) FROM students;
# ```
#
# Оказывается, эти невидимые значения имеют ненулевую длину. Что делать, чтобы не допустить таких значений-невидимок? Один из способов: возложить проверку таких ситуаций на прикладную программу. А что можно сделать на уровне определения таблицы `students`? Какое ограничение нужно предложить? В разделе 9.4 документации «Строковые функции и операторы» есть функция `trim`. Попробуйте воспользоваться ею. Если вы еще не изучили команду `ALTER TABLE`, то удалите таблицу `students` и создайте ее заново с учетом нового ограничения, а если уже познакомились с ней, то сделайте так:
# ```sql
# ALTER TABLE students ADD CHECK (...);
# ```
#
# Есть ли подобные слабые места в таблице «Успеваемость» (`progress`)?

# %% [markdown]
# ### Решение

# %% [markdown]
# #### Добавление ограничения

# %%
# %%sql
# -- Удаление записей
# DELETE FROM students;
#
# -- Добавление ограничения
# ALTER TABLE IF EXISTS students
#     ADD CONSTRAINT check_not_empty_name CHECK (length(trim(name)) != 0);
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# Done.
# []

# %% [markdown]
# #### Вставка NULL-значения

# %%
# %%sql
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11111, null, 1111, 111111);
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.NotNullViolation) null value in column "name" of relation "students" violates not-null constraint
# DETAIL:  Failing row contains (11111, null, 1111, 111111).
#
# [SQL: INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11111, null, 1111, 111111);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# #### Вставка пустой строки

# %%
# %%sql
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11111, '', 1111, 111111);
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.CheckViolation) new row for relation "students" violates check constraint "check_not_empty_name"
# DETAIL:  Failing row contains (11111, , 1111, 111111).
#
# [SQL: INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11111, '', 1111, 111111);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# #### Втавка строки из одного пробела

# %%
# %%sql
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11111, ' ', 1111, 111111);
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.CheckViolation) new row for relation "students" violates check constraint "check_not_empty_name"
# DETAIL:  Failing row contains (11111,  , 1111, 111111).
#
# [SQL: INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11111, ' ', 1111, 111111);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# #### Вставка строки из нескольких пробелов

# %%
# %%sql
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11111, '       ', 1111, 111111);
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.CheckViolation) new row for relation "students" violates check constraint "check_not_empty_name"
# DETAIL:  Failing row contains (11111,        , 1111, 111111).
#
# [SQL: INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11111, '       ', 1111, 111111);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# #### Вставка строки не только с пробелами

# %%
# %%sql
# INSERT INTO students (record_book, name, doc_ser, doc_num)
#     VALUES (11111, '   Иван   ', 1111, 111111)
# RETURNING name, length(name);
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# [('   Иван   ', 10)]

# %% [markdown]
# ## Задание 10
#
# В таблице «Студенты» (`students`) атрибут «Серия документа, удостоверяющего личность» (`doc_ser`) имеет числовой тип, однако в сериях таких документов могут встречаться лидирующие нули, которые в числовых столбцах не сохраняются. Например, при записи значения серии «0402» первый ноль не сохранится.
#
# Модифицируйте таблицу `students`, заменив числовой тип данных на символьный, например, `character`. Как вы думаете, эта операция пройдет без затруднений или они все же возможны? Проверьте ваши предположения, выполнив модификацию.

# %% [markdown]
# ### Решение

# %% [markdown]
# #### Модификация типа данных поля `doc_ser`, когда нет внешних ключей на него

# %%
# %%sql
# -- Предварительно удалим таблицы
# DROP TABLE IF EXISTS students, progress, subject CASCADE;
#
# -- Создадим заново
# CREATE TABLE students (
#     record_book numeric(5) NOT NULL UNIQUE,
#     name text NOT NULL,
#     doc_ser numeric(4),
#     doc_num numeric(6),
#     PRIMARY KEY (doc_ser, doc_num)
# );
#
# -- Модификация типа данных поля `doc_ser` возможна
# ALTER TABLE IF EXISTS students
#     ALTER COLUMN doc_ser SET DATA TYPE char(4);
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# Done.
# Done.
# []

# %% [markdown]
# #### Модификация типа данных поля doc_ser, когда есть внешние ключи на него

# %%
# %%sql
# -- Предварительно удалим таблицы
# DROP TABLE IF EXISTS students, progress, subjects CASCADE;
#
# -- Создадим заново
# CREATE TABLE students (
#     record_book numeric(5) NOT NULL UNIQUE,
#     name text NOT NULL,
#     doc_ser numeric(4),
#     doc_num numeric(6),
#     PRIMARY KEY (doc_ser, doc_num)
# );
#
# CREATE TABLE progress (
#     doc_ser numeric(4),
#     doc_num numeric(6),
#     subject text NOT NULL,
#     acad_year text NOT NULL,
#     term numeric( 1 ) NOT NULL CHECK ( term = 1 OR term = 2 ),
#     mark numeric( 1 ) NOT NULL CHECK ( mark >= 3 AND mark <= 5 )
#         DEFAULT 5,
#     CONSTRAINT progress_doc_ser_doc_num_fkey
#         FOREIGN KEY (doc_ser, doc_num)
#         REFERENCES students (doc_ser, doc_num)
#         ON UPDATE CASCADE
#         ON DELETE CASCADE
# );
#
# -- Модификация типа данных поля `doc_ser` пройдет с ошибкой
# ALTER TABLE IF EXISTS students
#     ALTER COLUMN doc_ser SET DATA TYPE char(4);
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# Done.
# Done.
# (psycopg2.errors.DatatypeMismatch) foreign key constraint "progress_doc_ser_doc_num_fkey" cannot be implemented
# DETAIL:  Key columns "doc_ser" and "doc_ser" are of incompatible types: numeric and character.
#
# [SQL: -- Модификация типа данных поля `doc_ser` пройдет с ошибкой
# ALTER TABLE IF EXISTS students
#     ALTER COLUMN doc_ser SET DATA TYPE char(4);]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ## Задание 11
#
# В таблице «Рейсы» (`flights`) есть ограничение, которое регулирует соотношения значений фактического времени вылета и фактического времени прилета. Как вы думаете, не является ли выражение `actual_arrival IS NOT NULL` во второй части условного оператора `OR` избыточным?
# ```sql
# CREATE TABLE flights
# ( ...
#     CHECK ( actual_arrival IS NULL OR
#             ( actual_departure IS NOT NULL AND
#                 actual_arrival IS NOT NULL AND
#                 actual_arrival > actual_departure
#             )
# ),
# ...
# ```
#
# Проверьте ваши предположения на практике. Для этого сначала удалите существующее ограничение с помощью команды
# ```sql
# ALTER TABLE flights DROP CONSTRAINT имя-ограничения;
# ```
#
# Как определить имя этого ограничения? С помощью команды
# ```
# \d flights
# ```
#
# получите описание таблицы `flights`, а в нем есть названия всех ограничений.
#
# Затем sсоздайте это же ограничение, но в модифицированном виде:\
# ```sql
# ALTER TABLE flights
#     ADD CHECK ( actual_arrival IS NULL OR
#         ( actual_departure IS NOT NULL AND
#             actual_arrival > actual_departure
#         )
# );
# ```
#
# Попробуйте добавить в таблицу `flights` две-три строки, подбирая такие значения атрибутов `actual_departure` и `actual_arrival`, чтобы проверить все возможные исходы этих проверок. Конечно, вместо добавления новых строк можно модифицировать одну и ту же строку с помощью команды `UPDATE`.

# %% [markdown]
# ### Решение

# %% [markdown]
# Да, выражение `actual_arrival IS NOT NULL` во второй части условного оператора `OR` является избыточным.

# %% [markdown]
# #### Удаление существующего ограничения и добавление нового

# %%
# %%sql
# -- Удаление существующего ограничения
# ALTER TABLE IF EXISTS flights
#     DROP CONSTRAINT flights_check1;
#
# -- Создание нового ограничения
# ALTER TABLE IF EXISTS flights
#     ADD CONSTRAINT flights_check1 CHECK (
#         actual_arrival IS NULL
#         OR (
#             actual_departure IS NOT NULL
#             AND actual_arrival > actual_departure
#         )
#     );
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# Done.
# []

# %% [markdown]
# #### Строка, с которой будут эксперименты

# %%
# %%sql
# SELECT * FROM flights WHERE flight_id = 1;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# [(1, 'PG0405', datetime.datetime(2017, 6, 12, 6, 35, tzinfo=datetime.timezone.utc), datetime.datetime(2017, 6, 12, 7, 30, tzinfo=datetime.timezone.utc), 'DME', 'LED', 'Arrived', '321', datetime.datetime(2017, 6, 12, 6, 39, tzinfo=datetime.timezone.utc), datetime.datetime(2017, 6, 12, 7, 35, tzinfo=datetime.timezone.utc))]

# %% [markdown]
# #### `SET actual_arrival = null, actual_departure = <timestamp>` - нет ошибок

# %%
# %%sql
# UPDATE flights
#     SET
#         actual_arrival = null,
#         actual_departure = '2017-06-12 06:39:00+00:00'::timestamp
# WHERE
#     flight_id = 1
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# [(1, 'PG0405', datetime.datetime(2017, 6, 12, 6, 35, tzinfo=datetime.timezone.utc), datetime.datetime(2017, 6, 12, 7, 30, tzinfo=datetime.timezone.utc), 'DME', 'LED', 'Arrived', '321', datetime.datetime(2017, 6, 12, 6, 39, tzinfo=datetime.timezone.utc), None)]

# %% [markdown]
# #### `SET actual_arrival = null, actual_departure = null` - нет ошибок

# %%
# %%sql
# UPDATE flights
#     SET
#         actual_arrival = null,
#         actual_departure = null
# WHERE
#     flight_id = 1
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# [(1, 'PG0405', datetime.datetime(2017, 6, 12, 6, 35, tzinfo=datetime.timezone.utc), datetime.datetime(2017, 6, 12, 7, 30, tzinfo=datetime.timezone.utc), 'DME', 'LED', 'Arrived', '321', None, None)]

# %% [markdown]
# #### `SET actual_arrival = <timestamp>, actual_departure = null` - ошибка ограничения

# %%
# %%sql
# UPDATE flights
#     SET
#         actual_arrival = '2017-06-12 07:35:00+00:00'::timestamp,
#         actual_departure = null
# WHERE
#     flight_id = 1
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.CheckViolation) new row for relation "flights" violates check constraint "flights_check1"
# DETAIL:  Failing row contains (1, PG0405, 2017-06-12 06:35:00+00, 2017-06-12 07:30:00+00, DME, LED, Arrived, 321, null, 2017-06-12 07:35:00+00).
#
# [SQL: UPDATE flights
#     SET
#         actual_arrival = '2017-06-12 07:35:00+00:00'::timestamp,
#         actual_departure = null
# WHERE
#     flight_id = 1
# RETURNING *;]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# #### `SET actual_arrival = <timestamp>, actual_departure = <timestamp>` - ошибка, потому что `actual_arrival <= actual_departure`

# %%
# %%sql
# UPDATE flights
#     SET
#         actual_arrival = '2017-06-12 05:35:00+00:00'::timestamp,
#         actual_departure = '2017-06-12 06:39:00+00:00'::timestamp
# WHERE
#     flight_id = 1
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# (psycopg2.errors.CheckViolation) new row for relation "flights" violates check constraint "flights_check1"
# DETAIL:  Failing row contains (1, PG0405, 2017-06-12 06:35:00+00, 2017-06-12 07:30:00+00, DME, LED, Arrived, 321, 2017-06-12 06:39:00+00, 2017-06-12 05:35:00+00).
#
# [SQL: UPDATE flights
#     SET
#         actual_arrival = '2017-06-12 05:35:00+00:00'::timestamp,
#         actual_departure = '2017-06-12 06:39:00+00:00'::timestamp
# WHERE
#     flight_id = 1
# RETURNING *;]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# #### `SET actual_arrival = <timestamp>, actual_departure = <timestamp>` - нет ошибок

# %%
# %%sql
# UPDATE flights
#     SET
#         actual_arrival = '2017-06-12 07:35:00+00:00'::timestamp,
#         actual_departure = '2017-06-12 06:39:00+00:00'::timestamp
# WHERE
#     flight_id = 1
# RETURNING *;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 1 rows affected.
# [(1, 'PG0405', datetime.datetime(2017, 6, 12, 6, 35, tzinfo=datetime.timezone.utc), datetime.datetime(2017, 6, 12, 7, 30, tzinfo=datetime.timezone.utc), 'DME', 'LED', 'Arrived', '321', datetime.datetime(2017, 6, 12, 6, 39, tzinfo=datetime.timezone.utc), datetime.datetime(2017, 6, 12, 7, 35, tzinfo=datetime.timezone.utc))]

# %% [markdown]
# ## Задание 12
#
# Команда `ALTER TABLE` позволяет переименовать таблицу. Например:
# ```sql
# ALTER TABLE table_name RENAME TO new_table_name;
# ```
#
# Поскольку в командах создания таблиц базы данных «Авиаперевозки» мы не указывали имена ограничений для первичных и внешних ключей, то их имена были сформированы автоматически самой СУБД. Как вы думаете, получили ли эти ограничения новые имена после переименования таблицы?
#
# Проверьте ваши предположения, выполнив такую операцию с одной из таблиц базы данных «Авиаперевозки», имеющих внешние ключи.

# %% [markdown]
# ### Решение

# %% [markdown]
# Имена ограничений не изменятся, если переименовать таблицу.

# %% [markdown]
# #### Текущие ограничения таблицы `boarding_passes`

# %%
# %%sql
# SELECT
#     constraint_name,
#     table_name,
#     column_name,
#     ordinal_position
# FROM information_schema.key_column_usage
# WHERE
#     table_name = 'boarding_passes';
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# 8 rows affected.
# [('boarding_passes_ticket_no_fkey', 'boarding_passes', 'ticket_no', 1),
#  ('boarding_passes_pkey', 'boarding_passes', 'ticket_no', 1),
#  ('boarding_passes_ticket_no_fkey', 'boarding_passes', 'flight_id', 2),
#  ('boarding_passes_pkey', 'boarding_passes', 'flight_id', 2),
#  ('boarding_passes_flight_id_seat_no_key', 'boarding_passes', 'flight_id', 1),
#  ('boarding_passes_flight_id_boarding_no_key', 'boarding_passes', 'flight_id', 1),
#  ('boarding_passes_flight_id_boarding_no_key', 'boarding_passes', 'boarding_no', 2),
#  ('boarding_passes_flight_id_seat_no_key', 'boarding_passes', 'seat_no', 2)]

# %% [markdown]
# #### Имена ограничений не изменятся, если переименовать таблицу

# %%
# %%sql
# -- Переименование таблицы
# ALTER TABLE IF EXISTS boarding_passes RENAME TO bp;
#
# -- Имена ограничений не изменились
# SELECT
#     constraint_name,
#     table_name,
#     column_name,
#     ordinal_position
# FROM information_schema.key_column_usage
# WHERE
#     table_name = 'bp';
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# 8 rows affected.
# [('boarding_passes_ticket_no_fkey', 'bp', 'ticket_no', 1),
#  ('boarding_passes_pkey', 'bp', 'ticket_no', 1),
#  ('boarding_passes_ticket_no_fkey', 'bp', 'flight_id', 2),
#  ('boarding_passes_pkey', 'bp', 'flight_id', 2),
#  ('boarding_passes_flight_id_seat_no_key', 'bp', 'flight_id', 1),
#  ('boarding_passes_flight_id_boarding_no_key', 'bp', 'flight_id', 1),
#  ('boarding_passes_flight_id_boarding_no_key', 'bp', 'boarding_no', 2),
#  ('boarding_passes_flight_id_seat_no_key', 'bp', 'seat_no', 2)]

# %% [markdown]
# #### Восстановление имени таблицы `boarding_passes`

# %%
# %%sql
# ALTER TABLE bp RENAME TO boarding_passes;
# Out:
#  * postgresql://postgres:***@postgres_basic.demodb:5432/demo
# Done.
# []
